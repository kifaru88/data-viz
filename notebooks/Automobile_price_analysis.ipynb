# %%
#importing a csv into python
import pandas as pd
df = pd.read_csv('/home/kifaru/projects/data-viz/Data/auto.csv',header=None)
df.head() #shows the first rows of the dataframe
# Out:
#           0                  1            2          3           4   \
# 0  symboling  normalized-losses         make  fuel-type  aspiration
# 1          3                  ?  alfa-romero        gas         std
# 2          3                  ?  alfa-romero        gas         std
# 3          1                  ?  alfa-romero        gas         std
# 4          2                164         audi        gas         std
#
#              5            6             7                8           9   ...  \
# 0  num-of-doors   body-style  drive-wheels  engine-location  wheel-base  ...
# 1           two  convertible           rwd            front        88.6  ...
# 2           two  convertible           rwd            front        88.6  ...
# 3           two    hatchback           rwd            front        94.5  ...
# 4          four        sedan           fwd            front        99.8  ...
#
#             16           17    18      19                 20          21  \
# ...

# %%
#Adding headers(Column Names)
headers = [
    "symboling", "normalized-losses", "make", "fuel-type", "aspiration",
    "num-of-doors", "body-style", "drive-wheels", "engine-location",
    "wheel-base", "length", "width", "height", "curb-weight",
    "engine-type", "num-of-cylinders", "engine-size", "fuel-system",
    "bore", "stroke", "compression-ratio", "horsepower", "peak-rpm",
    "city-mpg", "highway-mpg", "price"
]

# %%
df.columns = headers
df.head()
# Out:
#    symboling  normalized-losses         make  fuel-type  aspiration  \
# 0  symboling  normalized-losses         make  fuel-type  aspiration
# 1          3                  ?  alfa-romero        gas         std
# 2          3                  ?  alfa-romero        gas         std
# 3          1                  ?  alfa-romero        gas         std
# 4          2                164         audi        gas         std
#
#    num-of-doors   body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0  num-of-doors   body-style  drive-wheels  engine-location  wheel-base  ...
# 1           two  convertible           rwd            front        88.6  ...
# 2           two  convertible           rwd            front        88.6  ...
# 3           two    hatchback           rwd            front        94.5  ...
# 4          four        sedan           fwd            front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke  compression-ratio  horsepower  \
# ...

# %%
#Exporting a pandas DataFrame to csv/Excel/Json/SQL
df.to_csv("/home/kifaru/Desktop/auto.csv", index=False)

#df.to_excel("/home/kifaru/Desktop/auto.xlsx", index=False)
#df.to_json("/home/kifaru/Desktop/auto.json", index=False)
#df.to_sql("/home/kifaru/Desktop/auto.sql", index=False)

# %%
#understanding the data
df.dtypes
# Out:
# symboling            str
# normalized-losses    str
# make                 str
# fuel-type            str
# aspiration           str
# num-of-doors         str
# body-style           str
# drive-wheels         str
# engine-location      str
# wheel-base           str
# length               str
# width                str
# height               str
# curb-weight          str
# engine-type          str
# num-of-cylinders     str
# engine-size          str
# fuel-system          str
# bore                 str
# stroke               str
# compression-ratio    str
# horsepower           str
# peak-rpm             str
# city-mpg             str
# highway-mpg          str
# price                str
# dtype: object

# %%
#Statistical summary-numerical summary
df.describe()
# Out:
#        symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# count        206               206     206       206        206          206
# unique         7                53      23         3          3            4
# top            0                 ?  toyota       gas        std         four
# freq          67                41      32       185        168          114
#
#        body-style drive-wheels engine-location wheel-base  ... engine-size  \
# count         206          206             206        206  ...         206
# unique          6            4               3         54  ...          45
# top         sedan          fwd           front       94.5  ...         122
# freq           96          120             202         21  ...          15
#
#        fuel-system  bore stroke compression-ratio horsepower peak-rpm  \
# count          206   206    206               206        206      206
# ...

# %%
#descriptive statistics for ALL columns
df.describe(include="all")
# Out:
#        symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# count        206               206     206       206        206          206
# unique         7                53      23         3          3            4
# top            0                 ?  toyota       gas        std         four
# freq          67                41      32       185        168          114
#
#        body-style drive-wheels engine-location wheel-base  ... engine-size  \
# count         206          206             206        206  ...         206
# unique          6            4               3         54  ...          45
# top         sedan          fwd           front       94.5  ...         122
# freq           96          120             202         21  ...          15
#
#        fuel-system  bore stroke compression-ratio horsepower peak-rpm  \
# count          206   206    206               206        206      206
# ...

# %%
#concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          206 non-null    str
#  1   normalized-losses  206 non-null    str
#  2   make               206 non-null    str
#  3   fuel-type          206 non-null    str
#  4   aspiration         206 non-null    str
#  5   num-of-doors       206 non-null    str
#  6   body-style         206 non-null    str
#  7   drive-wheels       206 non-null    str
#  8   engine-location    206 non-null    str
#  9   wheel-base         206 non-null    str
#  10  length             206 non-null    str
#  11  width              206 non-null    str
#  12  height             206 non-null    str
#  13  curb-weight        206 non-null    str
#  14  engine-type        206 non-null    str
#  15  num-of-cylinders   206 non-null    str
#  16  engine-size        206 non-null    str
# ...

# %%
#Fixing the missing values
import numpy as np

df1 = df.replace("?", np.nan)

# %%
#Removing the incomplete rows
df = df1.dropna(subset=["price"], axis=0)
#view the data
df.head()
# Out:
#    symboling  normalized-losses         make  fuel-type  aspiration  \
# 0  symboling  normalized-losses         make  fuel-type  aspiration
# 1          3                NaN  alfa-romero        gas         std
# 2          3                NaN  alfa-romero        gas         std
# 3          1                NaN  alfa-romero        gas         std
# 4          2                164         audi        gas         std
#
#    num-of-doors   body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0  num-of-doors   body-style  drive-wheels  engine-location  wheel-base  ...
# 1           two  convertible           rwd            front        88.6  ...
# 2           two  convertible           rwd            front        88.6  ...
# 3           two    hatchback           rwd            front        94.5  ...
# 4          four        sedan           fwd            front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke  compression-ratio  horsepower  \
# ...

# %%
#Save the dataset
df.to_excel("/home/kifaru/Desktop/auto.xlsx" ,index=None)

# %%
#Check the data types
df.dtypes
# Out:
# symboling            str
# normalized-losses    str
# make                 str
# fuel-type            str
# aspiration           str
# num-of-doors         str
# body-style           str
# drive-wheels         str
# engine-location      str
# wheel-base           str
# length               str
# width                str
# height               str
# curb-weight          str
# engine-type          str
# num-of-cylinders     str
# engine-size          str
# fuel-system          str
# bore                 str
# stroke               str
# compression-ratio    str
# horsepower           str
# peak-rpm             str
# city-mpg             str
# highway-mpg          str
# price                str
# dtype: object

# %%
#Statistical summary
df.describe()
# Out:
#        symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# count        202               165     202       202        202          200
# unique         7                52      23         3          3            3
# top            0               161  toyota       gas        std         four
# freq          65                11      32       181        165          113
#
#        body-style drive-wheels engine-location wheel-base  ... engine-size  \
# count         202          202             202        202  ...         202
# unique          6            4               3         53  ...          44
# top         sedan          fwd           front       93.7  ...         122
# freq           94          118             198         20  ...          15
#
#        fuel-system  bore stroke compression-ratio horsepower peak-rpm  \
# count          202   198    198               202        200      200
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 202 entries, 0 to 205
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          202 non-null    str
#  1   normalized-losses  165 non-null    str
#  2   make               202 non-null    str
#  3   fuel-type          202 non-null    str
#  4   aspiration         202 non-null    str
#  5   num-of-doors       200 non-null    str
#  6   body-style         202 non-null    str
#  7   drive-wheels       202 non-null    str
#  8   engine-location    202 non-null    str
#  9   wheel-base         202 non-null    str
#  10  length             202 non-null    str
#  11  width              202 non-null    str
#  12  height             202 non-null    str
#  13  curb-weight        202 non-null    str
#  14  engine-type        202 non-null    str
#  15  num-of-cylinders   202 non-null    str
#  16  engine-size        202 non-null    str
# ...

# %%
#shows the last 5 rows
df.tail()
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 201        -1                95  volvo       gas        std         four
# 202        -1                95  volvo       gas      turbo         four
# 203        -1                95  volvo       gas        std         four
# 204        -1                95  volvo    diesel      turbo         four
# 205        -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location wheel-base  ... engine-size  \
# 201      sedan          rwd           front      109.1  ...         141
# 202      sedan          rwd           front      109.1  ...         141
# 203      sedan          rwd           front      109.1  ...         173
# 204      sedan          rwd           front      109.1  ...         145
# 205      sedan          rwd           front      109.1  ...         141
#
#     fuel-system  bore stroke compression-ratio horsepower peak-rpm city-mpg  \
# ...

# %%
#make the first row my column headers
df= df.drop(index=0).reset_index(drop=True)

# %%
print(df.columns.tolist())
# Out:
# ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
#Converts the column to numeric 
df["normalized-losses"] = pd.to_numeric(
    df["normalized-losses"],
    errors="coerce"
)

# %%
df["normalized-losses"] = df["normalized-losses"].replace("", np.nan)
mean =df['normalized-losses'].mean()
print(mean)
# Out:
# 122.0

# %%
df["normalized-losses"] = df["normalized-losses"].replace(np.nan, mean)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    str
#  1   normalized-losses  201 non-null    float64
#  2   make               201 non-null    str
#  3   fuel-type          201 non-null    str
#  4   aspiration         201 non-null    str
#  5   num-of-doors       199 non-null    str
#  6   body-style         201 non-null    str
#  7   drive-wheels       201 non-null    str
#  8   engine-location    201 non-null    str
#  9   wheel-base         201 non-null    str
#  10  length             201 non-null    str
#  11  width              201 non-null    str
#  12  height             201 non-null    str
#  13  curb-weight        201 non-null    str
#  14  engine-type        201 non-null    str
#  15  num-of-cylinders   201 non-null    str
#  16  engine-size        201 non-null    str
# ...

# %%
df.to_excel("/home/kifaru/Desktop/auto.xlsx",index=False)

# %%
#Correcting datatypes
df["city-mpg"] = df["city-mpg"].astype("int")

# %%
#Applying Calculations to entire columns
df["city-mpg"] = 235/df["city-mpg"]

# %%
df.rename(columns={"city-mpg":"city-L/100km"}, inplace=True)

# %%
df['city-L/100km'].head()
# Out:
# 0    11.190476
# 1    11.190476
# 2    12.368421
# 3     9.791667
# 4    13.055556
# Name: city-L/100km, dtype: float64

# %%
df.head()
# Out:
#   symboling  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0         3              122.0  alfa-romero       gas        std          two
# 1         3              122.0  alfa-romero       gas        std          two
# 2         1              122.0  alfa-romero       gas        std          two
# 3         2              164.0         audi       gas        std         four
# 4         2              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ... engine-size  \
# 0  convertible          rwd           front       88.6  ...         130
# 1  convertible          rwd           front       88.6  ...         130
# 2    hatchback          rwd           front       94.5  ...         152
# 3        sedan          fwd           front       99.8  ...         109
# 4        sedan          4wd           front       99.4  ...         136
#
# ...

# %%
#Exporting a pandas dataframe to Excel
df.to_excel("/home/kifaru/Desktop/auto.xlsx",index=False)

# %%
#Converting the datatypes
df = df.astype({"price":"int","horsepower":"float"})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    str
#  1   normalized-losses  201 non-null    float64
#  2   make               201 non-null    str
#  3   fuel-type          201 non-null    str
#  4   aspiration         201 non-null    str
#  5   num-of-doors       199 non-null    str
#  6   body-style         201 non-null    str
#  7   drive-wheels       201 non-null    str
#  8   engine-location    201 non-null    str
#  9   wheel-base         201 non-null    str
#  10  length             201 non-null    str
#  11  width              201 non-null    str
#  12  height             201 non-null    str
#  13  curb-weight        201 non-null    str
#  14  engine-type        201 non-null    str
#  15  num-of-cylinders   201 non-null    str
#  16  engine-size        201 non-null    str
# ...

# %%
#Data Normalization
#Simple feature scaling
df["length"]= pd.to_numeric(df["length"],errors="coerce")
df["length"] = df["length"]/df["length"].max()

df["width"] = pd.to_numeric(df["width"],errors="coerce")
df["width"]= df["width"]/df["width"].max()

df["height"] = pd.to_numeric(df["height"],errors="coerce")
df["height"]= df["height"]/df["height"].max()

df.head()
# Out:
#   symboling  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0         3              122.0  alfa-romero       gas        std          two
# 1         3              122.0  alfa-romero       gas        std          two
# 2         1              122.0  alfa-romero       gas        std          two
# 3         2              164.0         audi       gas        std         four
# 4         2              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ...  engine-size  \
# 0  convertible          rwd           front       88.6  ...          130
# 1  convertible          rwd           front       88.6  ...          130
# 2    hatchback          rwd           front       94.5  ...          152
# 3        sedan          fwd           front       99.8  ...          109
# 4        sedan          4wd           front       99.4  ...          136
#
# ...

# %%
df.to_excel("/home/kifaru/Downloads/auto.xlsx" , index=False)

# %%
#Numeric to categorical varibles
bins = np.linspace(min(df["price"]),max(df["price"]),4)

group_names = ["low","medium","high"]

df["price-binned"] = pd.cut(df["price"],bins,labels = group_names, include_lowest=True)

# %%
df.head()
# Out:
#   symboling  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0         3              122.0  alfa-romero       gas        std          two
# 1         3              122.0  alfa-romero       gas        std          two
# 2         1              122.0  alfa-romero       gas        std          two
# 3         2              164.0         audi       gas        std         four
# 4         2              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ...  fuel-system  \
# 0  convertible          rwd           front       88.6  ...         mpfi
# 1  convertible          rwd           front       88.6  ...         mpfi
# 2    hatchback          rwd           front       94.5  ...         mpfi
# 3        sedan          fwd           front       99.8  ...         mpfi
# 4        sedan          4wd           front       99.4  ...         mpfi
#
# ...

# %%
df.tail()
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 196        -1               95.0  volvo       gas        std         four
# 197        -1               95.0  volvo       gas      turbo         four
# 198        -1               95.0  volvo       gas        std         four
# 199        -1               95.0  volvo    diesel      turbo         four
# 200        -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location wheel-base  ...  fuel-system  \
# 196      sedan          rwd           front      109.1  ...         mpfi
# 197      sedan          rwd           front      109.1  ...         mpfi
# 198      sedan          rwd           front      109.1  ...         mpfi
# 199      sedan          rwd           front      109.1  ...          idi
# 200      sedan          rwd           front      109.1  ...         mpfi
#
#      bore  stroke compression-ratio horsepower peak-rpm city-L/100km  \
# ...

# %%
#Categorical variables to numeric/Quantitative variables
pd.get_dummies(df["fuel-type"])
# Out:
#      diesel    gas
# 0     False   True
# 1     False   True
# 2     False   True
# 3     False   True
# 4     False   True
# ..      ...    ...
# 196   False   True
# 197   False   True
# 198   False   True
# 199    True  False
# 200   False   True
#
# [201 rows x 2 columns]

# %%
df.head()
# Out:
#   symboling  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0         3              122.0  alfa-romero       gas        std          two
# 1         3              122.0  alfa-romero       gas        std          two
# 2         1              122.0  alfa-romero       gas        std          two
# 3         2              164.0         audi       gas        std         four
# 4         2              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ...  fuel-system  \
# 0  convertible          rwd           front       88.6  ...         mpfi
# 1  convertible          rwd           front       88.6  ...         mpfi
# 2    hatchback          rwd           front       94.5  ...         mpfi
# 3        sedan          fwd           front       99.8  ...         mpfi
# 4        sedan          4wd           front       99.4  ...         mpfi
#
# ...

# %%
#Evaluating missing data
df.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 196      False              False  False      False       False         False
# 197      False              False  False      False       False         False
# 198      False              False  False      False       False         False
# 199      False              False  False      False       False         False
# 200      False              False  False      False       False         False
#
# ...

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False              False  False      False       False         False
# 1      False              False  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  fuel-system  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
df.notnull()
df.to_excel("/home/kifaru/Documents/auto.xlsx" ,index=False)

# %%
#Count missing values in each column
for column in missing_data.columns.values.tolist():
  #print(column)
  print(missing_data[column].value_counts())
  print("")
# Out:
# symboling
# False    201
# Name: count, dtype: int64
#
# normalized-losses
# False    201
# Name: count, dtype: int64
#
# make
# False    201
# Name: count, dtype: int64
#
# fuel-type
# False    201
# Name: count, dtype: int64
#
# aspiration
# False    201
# Name: count, dtype: int64
#
# num-of-doors
# False    199
# True       2
# Name: count, dtype: int64
#
# body-style
# False    201
# Name: count, dtype: int64
#
# drive-wheels
# False    201
# Name: count, dtype: int64
#
# engine-location
# False    201
# Name: count, dtype: int64
#
# wheel-base
# False    201
# Name: count, dtype: int64
#
# length
# False    201
# Name: count, dtype: int64
#
# width
# False    201
# Name: count, dtype: int64
#
# height
# False    201
# Name: count, dtype: int64
#
# curb-weight
# False    201
# Name: count, dtype: int64
#
# engine-type
# False    201
# Name: count, dtype: int64
#
# num-of-cylinders
# False    201
# Name: count, dtype: int64
#
# engine-size
# False    201
# ...

# %%
#df["stroke"] = pd.to_numeric(df["stroke"],errors="coerce")
#mean = df["stroke"].mean()

# %%
#Converting the datatype and calculating the mean of stroke
avg_stroke = df["stroke"].astype("float").mean(axis=0)
print("avg_stroke:",avg_stroke)
# Out:
# avg_stroke: 3.256903553299492

# %%
#Replacing missing values with the mean in stroke
df["stroke"] = df["stroke"].replace(np.nan,avg_stroke)

# %%
#Converting the datatype and calculating the mean of bore
avg_bore = df["bore"].astype("float").mean(axis=0)
print("avg_bore:",avg_bore)
# Out:
# avg_bore: 3.330710659898477

# %%
#Replacing missing values with the mean in bore
df["bore"] = df["bore"].replace(np.nan,avg_bore)

# %%
#Converting the datatype and calculating the mean of peak_rpm
avg_peak_rpm = df["peak-rpm"].astype("float").mean(axis=0)

# %%
#Replacing missing values with the mean in peak_rpm
df["peak-rpm"] = df["peak-rpm"].replace(np.nan,avg_peak_rpm)

# %%
#Converting the datatype and calculating the mean of horsepower
avg_horsepower = df["horsepower"].astype("float").mean(axis=0)
print(f"average horsepower:{avg_horsepower}")
# Out:
# average horsepower:103.39698492462311

# %%
#Replacing missing values with the mean in horsepower
df["horsepower"] = df["horsepower"].replace(np.nan,avg_horsepower)

# %%
df.head()
# Out:
#   symboling  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0         3              122.0  alfa-romero       gas        std          two
# 1         3              122.0  alfa-romero       gas        std          two
# 2         1              122.0  alfa-romero       gas        std          two
# 3         2              164.0         audi       gas        std         four
# 4         2              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ...  fuel-system  \
# 0  convertible          rwd           front       88.6  ...         mpfi
# 1  convertible          rwd           front       88.6  ...         mpfi
# 2    hatchback          rwd           front       94.5  ...         mpfi
# 3        sedan          fwd           front       99.8  ...         mpfi
# 4        sedan          4wd           front       99.4  ...         mpfi
#
# ...

# %%
df.describe(include="all")
# Out:
#        symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# count        201          201.00000     201       201        201          199
# unique         6                NaN      22         2          2            2
# top            0                NaN  toyota       gas        std         four
# freq          65                NaN      32       181        165          113
# mean         NaN          122.00000     NaN       NaN        NaN          NaN
# std          NaN           31.99625     NaN       NaN        NaN          NaN
# min          NaN           65.00000     NaN       NaN        NaN          NaN
# 25%          NaN          101.00000     NaN       NaN        NaN          NaN
# 50%          NaN          122.00000     NaN       NaN        NaN          NaN
# 75%          NaN          137.00000     NaN       NaN        NaN          NaN
# max          NaN          256.00000     NaN       NaN        NaN          NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    str
#  1   normalized-losses  201 non-null    float64
#  2   make               201 non-null    str
#  3   fuel-type          201 non-null    str
#  4   aspiration         201 non-null    str
#  5   num-of-doors       199 non-null    str
#  6   body-style         201 non-null    str
#  7   drive-wheels       201 non-null    str
#  8   engine-location    201 non-null    str
#  9   wheel-base         201 non-null    str
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    str
#  14  engine-type        201 non-null    str
#  15  num-of-cylinders   201 non-null    str
#  16  engine-size        201 non-null    str
# ...

# %%
df.tail()
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 196        -1               95.0  volvo       gas        std         four
# 197        -1               95.0  volvo       gas      turbo         four
# 198        -1               95.0  volvo       gas        std         four
# 199        -1               95.0  volvo    diesel      turbo         four
# 200        -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location wheel-base  ...  fuel-system  \
# 196      sedan          rwd           front      109.1  ...         mpfi
# 197      sedan          rwd           front      109.1  ...         mpfi
# 198      sedan          rwd           front      109.1  ...         mpfi
# 199      sedan          rwd           front      109.1  ...          idi
# 200      sedan          rwd           front      109.1  ...         mpfi
#
#      bore  stroke compression-ratio horsepower peak-rpm city-L/100km  \
# ...

# %%
df["peak-rpm"].isnull().sum()
# Out:
# np.int64(0)

# %%
#Values present in a particular column
df["num-of-doors"].value_counts()
#df["fuel-type"].value_counts()
# Out:
# num-of-doors
# four    113
# two      86
# Name: count, dtype: int64

# %%
#Values present in a particular column and then calculate the frequency
df["num-of-doors"].value_counts().idxmax()
#df["fuel-type"].value_counts().idxmax()
# Out:
# 'four'

# %%
df["num-of-doors"]= df["num-of-doors"].replace(np.nan,"four")

# %%
df["num-of-doors"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# Name: num-of-doors, Length: 201, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    str
#  1   normalized-losses  201 non-null    float64
#  2   make               201 non-null    str
#  3   fuel-type          201 non-null    str
#  4   aspiration         201 non-null    str
#  5   num-of-doors       201 non-null    str
#  6   body-style         201 non-null    str
#  7   drive-wheels       201 non-null    str
#  8   engine-location    201 non-null    str
#  9   wheel-base         201 non-null    str
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    str
#  14  engine-type        201 non-null    str
#  15  num-of-cylinders   201 non-null    str
#  16  engine-size        201 non-null    str
# ...

# %%
#Converting multiple column data types
df[["bore","stroke"]] = df[["stroke","bore"]].astype("float")

# %%
df["peak-rpm"] = df["peak-rpm"].astype("float")

# %%
#Visualizing Binned data
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import pyplot

plt.hist(df["price-binned"])

plt.xlabel("price")
plt.ylabel("count")
plt.title("price bins")
# Out:
# Text(0.5, 1.0, 'price bins')

# %%
#horsepower binned
bins = np.linspace(min(df["horsepower"]),max(df["horsepower"]),4)

group_names = ["low","medium","high"]

df["horsepower-binned"]= pd.cut(df["horsepower"],bins, labels=group_names, include_lowest=True)

# %%
#Visualizing horsepower Binned data
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import pyplot

plt.hist(df["horsepower-binned"])

plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
#visualizing binned data(bar chart)
#%matplotlib inline
import matplotlib.pyplot as plt
#from matplotlib import pyplot

plt.bar(group_names, df["horsepower-binned"].value_counts())

plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower binned")

plt.show()

# %%
#Getting the indicator variables
dummy_variable_1 = pd.get_dummies(df["fuel-type"])

dummy_variable_1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
#dummy/indicator variables
dummy_variable_1.rename(columns={"gas":'fuel-type-gas',"diesel":'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0             False           True
# 1             False           True
# 2             False           True
# 3             False           True
# 4             False           True

# %%
df = pd.concat([df,dummy_variable_1],axis=1)

# %%
#df.drop("fuel-type", axis=1, inplace=True)
df.head()
# Out:
#   symboling  normalized-losses         make fuel-type aspiration num-of-doors  \
# 0         3              122.0  alfa-romero       gas        std          two
# 1         3              122.0  alfa-romero       gas        std          two
# 2         1              122.0  alfa-romero       gas        std          two
# 3         2              164.0         audi       gas        std         four
# 4         2              164.0         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ...  \
# 0  convertible          rwd           front       88.6  ...
# 1  convertible          rwd           front       88.6  ...
# 2    hatchback          rwd           front       94.5  ...
# 3        sedan          fwd           front       99.8  ...
# 4        sedan          4wd           front       99.4  ...
#
#    compression-ratio  horsepower  peak-rpm city-L/100km highway-mpg  price  \
# ...

# %%
drive_wheels_count = df["drive-wheels"].value_counts().to_frame()
print(drive_wheels_count)
type(drive_wheels_count)
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8
# pandas.DataFrame

# %%
drive_wheels_count.rename(columns={"drive-wheels":"value_counts"},inplace=True)
drive_wheels_count.index.name= 'drive_wheels'
print(drive_wheels_count.index.name)
# Out:
# drive_wheels

# %%
import seaborn as sns
sns.boxplot (x="drive-wheels", y="price", data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
y=df["price"]
x=df["engine-size"]
plt.scatter(x,y)

plt.title("scatterplot of engine size vs price")
plt.xlabel("engine-size")
plt.ylabel("price")

plt.show()

# %%
sns.scatterplot(x="engine-size", y="price", data=df)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
df_test = df[['drive-wheels','body-style','price']]

# %%
df_group = df_test.groupby(['drive-wheels','body-style'],as_index=False).mean()
df_group
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
df_pivot = df_group.pivot(index="drive-wheels",columns="body-style")
df_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
plt.pcolor(df_pivot, cmap="RdBu")
plt.colorbar()
plt.show()

# %%
avg_price = df.groupby("make", as_index=False)["price"].mean()
avg_price
# Out:
#              make         price
# 0     alfa-romero  15498.333333
# 1            audi  17859.166667
# 2             bmw  26118.750000
# 3       chevrolet   6007.000000
# 4           dodge   7875.444444
# 5           honda   8184.692308
# 6           isuzu   8916.500000
# 7          jaguar  34600.000000
# 8           mazda  10652.882353
# 9   mercedes-benz  33647.000000
# 10        mercury  16503.000000
# 11     mitsubishi   9239.769231
# 12         nissan  10415.666667
# 13         peugot  15489.090909
# 14       plymouth   7963.428571
# 15        porsche  31400.500000
# 16        renault   9595.000000
# 17           saab  15223.333333
# 18         subaru   8541.250000
# 19         toyota   9885.812500
# 20     volkswagen  10077.500000
# 21          volvo  18063.181818

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.bar(avg_price["make"],avg_price["price"])

plt.xlabel("vehicle make")
plt.ylabel("avrage_price")
plt.title("average price by vehicle make")

plt.xticks(rotation=90)

plt.show()

# %%
df_anova = df[["make","price"]]

# %%
grouped_anova = df_anova.groupby("make")

# %%
from scipy import stats
anova_results = stats.f_oneway(grouped_anova.get_group("honda")["price"],grouped_anova.get_group("subaru")["price"])

anova_results
# Out:
# F_onewayResult(statistic=np.float64(0.19744030127462608), pvalue=np.float64(0.6609478240622191))

# %%
anova_results_1 = stats.f_oneway(grouped_anova.get_group("honda")["price"],grouped_anova.get_group("jaguar")["price"])

anova_results_1
# Out:
# F_onewayResult(statistic=np.float64(400.925870564337), pvalue=np.float64(1.0586193512077847e-11))

# %%
df["engine-size"]=df["engine-size"].astype("float")

# %%
df["engine-size"].dtypes
# Out:
# dtype('float64')

# %%
#CORRELATION
sns.regplot(x="engine-size",y="price",data=df)
plt.ylim(0,)
# Out:
# (0.0, 53497.735644741995)

# %%
df["highway-mpg"] = df["highway-mpg"].astype("float")
df["highway-mpg"].dtypes

sns.regplot(x="highway-mpg",y="price",data=df)
plt.ylim(0,)
# Out:
# (0.0, 48176.17361114841)

# %%
df["peak-rpm"].dtypes
# Out:
# dtype('float64')

# %%
sns.regplot(x="peak-rpm",y="price",data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
df[["engine-size","price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
df[["highway-mpg","price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
df[["peak-rpm","price"]].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101542
# price    -0.101542  1.000000

# %%
sns.regplot(x="stroke",y="price",data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
df[["stroke","price"]].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.543154
# price   0.543154  1.000000

# %%
sns.boxplot(x="body-style",y="price",data=df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x="engine-location",y="price",data=df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %%
df.describe()
# Out:
#        normalized-losses      length       width      height  engine-size  \
# count          201.00000  201.000000  201.000000  201.000000   201.000000
# mean           122.00000    0.837102    0.915126    0.899108   126.875622
# std             31.99625    0.059213    0.029187    0.040933    41.546834
# min             65.00000    0.678039    0.837500    0.799331    61.000000
# 25%            101.00000    0.801538    0.890278    0.869565    98.000000
# 50%            122.00000    0.832292    0.909722    0.904682   120.000000
# 75%            137.00000    0.881788    0.925000    0.928094   141.000000
# max            256.00000    1.000000    1.000000    1.000000   326.000000
#
#              bore      stroke  horsepower     peak-rpm  city-L/100km  \
# count  201.000000  201.000000  201.000000   201.000000    201.000000
# mean     3.256904    3.330711  103.396985  5117.587940      9.944145
# std      0.316048    0.268072   37.365602   478.113178      2.534599
# ...

# %%
df.describe(include='all')
# Out:
#        symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# count        201          201.00000     201       201        201          201
# unique         6                NaN      22         2          2            2
# top            0                NaN  toyota       gas        std         four
# freq          65                NaN      32       181        165          115
# mean         NaN          122.00000     NaN       NaN        NaN          NaN
# std          NaN           31.99625     NaN       NaN        NaN          NaN
# min          NaN           65.00000     NaN       NaN        NaN          NaN
# 25%          NaN          101.00000     NaN       NaN        NaN          NaN
# 50%          NaN          122.00000     NaN       NaN        NaN          NaN
# 75%          NaN          137.00000     NaN       NaN        NaN          NaN
# max          NaN          256.00000     NaN       NaN        NaN          NaN
#
# ...

# %%
# engine-location as variable
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  count
# engine-location
# front              198
# rear                 3

# %%
df["num-of-doors"].unique()
# Out:
# <StringArray>
# ['two', 'four']
# Length: 2, dtype: str

# %%
df_group_two = df[['drive-wheels','body-style','price']]

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8096811975632286  with a P-value of P = 6.058444649709987e-48

# %%
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test2=df_gptest [['drive-wheels','price']].groupby(['drive-wheels'])
grouped_test2.head()
# Out:
#     drive-wheels  price
# 0            rwd  13495
# 1            rwd  16500
# 2            rwd  16500
# 3            fwd  13950
# 4            4wd  17450
# 5            fwd  15250
# 6            fwd  17710
# 7            fwd  18920
# 8            fwd  23875
# 9            rwd  16430
# 10           rwd  16925
# 136          4wd   7603
# 140          4wd   9233
# 141          4wd  11259
# 144          4wd   8013

# %%
df_gptest
# Out:
#     drive-wheels   body-style  price
# 0            rwd  convertible  13495
# 1            rwd  convertible  16500
# 2            rwd    hatchback  16500
# 3            fwd        sedan  13950
# 4            4wd        sedan  17450
# ..           ...          ...    ...
# 196          rwd        sedan  16845
# 197          rwd        sedan  19045
# 198          rwd        sedan  21485
# 199          rwd        sedan  22470
# 200          rwd        sedan  22625
#
# [201 rows x 3 columns]

# %%
grouped_test2.get_group('4wd')['price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 grouped_test2.get_group('4wd')['price']
#
# File ~/projects/data-viz/venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:885, in BaseGroupBy.get_group(self, name)
#     883         name = name[0]
#     884     else:
# --> 885         raise KeyError(name)
#     887 inds = self._get_index(name)
#     888 if not len(inds):
#
# KeyError: '4wd'

# %%
df_test3 = df[['body-style', 'price']]

# %%
df_grp = df_test3.groupby(['body-style'], as_index=False).mean()

# %%
df_grp['price']

df.head()

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
z = df[['horsepower','curb-weight','engine-size','highway-mpg']]
df["horsepower"] = df["horsepower"].replace(
    np.nan,
    df["horsepower"].mean()
)
z.isnull().sum()

# %%
lm.fit (z,df["price"])

# %%
yhat = lm.predict(z)

# %%
lm.intercept_

# %%
lm.coef_
