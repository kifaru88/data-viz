# %%
#import the necessary tools 
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(42)

size = np.random.rand(100) * 200
price = 50000 + 2500 * size + np.random.normal(0, 30000, 100)

data = pd.DataFrame({
    'Size': size,
    'Price': price
})

# %%
#Splitting the data into training and testing sets.
size_train,size_test,price_train,price_test = train_test_split(data[['Size']],data['Price'],test_size=0.2,random_state=42)

# %%
#Training the model
model = LinearRegression()
model.fit(size_train,price_train)
price_pred = model.predict(size_test)

# %%
#Finding the slope
model.coef_
# Out:
# array([2439.79709724])

# %%
#finding our intercept
model.intercept_
# Out:
# np.float64(54287.39958375698)

# %%
#checking data split
print("size_train:", size_train.shape)
print("size_test:", size_test.shape)
print("price_train:", price_train.shape)
print("price_test:", price_test.shape)
print("price_pred:", price_pred.shape)
# Out:
# size_train: (80, 1)
# size_test: (20, 1)
# price_train: (80,)
# price_test: (20,)
# price_pred: (20,)

# %%
#finding our mean absolute error
mae = mean_absolute_error(price_test,price_pred)
print(f"mean absolute error:{mae:.2f}")
# Out:
# mean absolute error:17740.28

# %%
# Predict a new house
model.predict([[150]])
# Out:
# /home/kifaru/projects/data-viz/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([420256.96417037])
